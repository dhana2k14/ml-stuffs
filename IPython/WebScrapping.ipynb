# %%
import pandas as pd
import sys, os
import urllib2
from bs4 import BeautifulSoup

# %%
url =  "http://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India"
page = urllib2.urlopen(url)
soup = BeautifulSoup(page)
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-6-115823d44494> in <module>()
#       1 url =  "http://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India"
# ----> 2 page = urllib2.urlopen(url)
#       3 soup = BeautifulSoup(page)
#
# C:\Users\33093\AppData\Local\Continuum\Anaconda2\lib\urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# C:\Users\33093\AppData\Local\Continuum\Anaconda2\lib\urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# ...

# %%
print soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of state and union territory capitals in India - Wikipedia, the free encyclopedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %%
url = "https://www.nyse.com/listings_directory/bond"
page = urllib2.urlopen(url)
soup = BeautifulSoup(page)
# Out:
# D:\Anaconda\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    NYSE Bond Directory
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="//static.theice.com/gotham/0.0.1/font.css" id="css-fonts" rel="stylesheet"/>
#   <link href="//static.theice.com/icegroupweb-styles/2.6.5/css/nyse-core.min.css" rel="stylesheet"/>
#   <link href="//static.theice.com/icegroupweb-styles/2.6.5/css/nyse-extended.min.css" rel="stylesheet"/>
#   <link href="//static.theice.com/icegroupweb-styles/2.6.5/css/nyse-lists.min.css" rel="stylesheet"/>
#   <link href="//static.theice.com/icegroupweb-styles/2.6.5/css/nyse-tables.min.css" rel="stylesheet"/>
#   <link href="//static.theice.com/favicons/1.0.0/nyse.ico" rel="shortcut icon" type="image/x-icon"/>
# ...

# %%
soup.title
# Out:
# <title>NYSE Bond Directory</title>

# %%
soup.title.string
# Out:
# u'NYSE Bond Directory'

# %%
all_links = soup.find_all('a')
for link in all_links:
    print link.get('href')

# %%
all_links = soup.find_all()

# %%
print all_links
# Out:
# [<html lang="en"><head><title>NYSE Bond Directory</title><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="//static.theice.com/gotham/0.0.1/font.css" id="css-fonts" rel="stylesheet"/><link href="//static.theice.com/icegroupweb-styles/2.6.5/css/nyse-core.min.css" rel="stylesheet"/><link href="//static.theice.com/icegroupweb-styles/2.6.5/css/nyse-extended.min.css" rel="stylesheet"/><link href="//static.theice.com/icegroupweb-styles/2.6.5/css/nyse-lists.min.css" rel="stylesheet"/><link href="//static.theice.com/icegroupweb-styles/2.6.5/css/nyse-tables.min.css" rel="stylesheet"/><link href="//static.theice.com/favicons/1.0.0/nyse.ico" rel="shortcut icon" type="image/x-icon"/><!--[if IE 9]><script>document.documentElement.className += ' ie9';</script><script src="//static.theice.com/html5-history-api/4.1.15/history.iegte8.js"></script><![endif]--><script>window.ICE = window.ICE || {};\nwindow.ICE.env = 'o
# ...

# %%
right_table = soup.find_all('table', {"class" : "wikitable sortable plainrowheaders"})

# %%
f = open('D:/PythonTutorials/sample_xml.xml')
right_table = f.read()

# %%
right_table
# Out:
# [<table class="wikitable sortable plainrowheaders">
#  <tr>
#  <th scope="col">No.</th>
#  <th scope="col">State/Union Territory</th>
#  <th scope="col">Administrative capitals</th>
#  <th scope="col">Legislative capitals</th>
#  <th scope="col">Judiciary capitals</th>
#  <th scope="col">Year capital was established</th>
#  <th scope="col">The Former capital</th>
#  </tr>
#  <tr>
#  <td>1</td>
#  <th scope="row"><a href="/wiki/Andaman_and_Nicobar_Islands" title="Andaman and Nicobar Islands">Andaman and Nicobar Islands</a> <img alt="union territory" data-file-height="14" data-file-width="9" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/></th>
#  <td><b><a href="/wiki/Port_Blair" title="Port Blair">Port Blair</a></b></td>
#  <td>Port Blair</td>
#  <td><a href="/wiki/Kolkata" title="Kolkata">Kolkata</a> (formerly Calcutta)</td>
#  <td>1956</td>
#  <td>Calcuta (1945–1956)</td>
#  </tr>
#  <tr>
#  <td>2</td>
# ...

# %%
A = []
B = []
C = []
D = []
E = []
F = []
G = []
for line in right_table:
    for row in line.find_all("tr"):
        cells = row.find_all('td')
        states = row.find_all('th')
        if len(cells) == 6:
            A.append(cells[0].find(text = True))
            B.append(states[0].find(text = True))
            C.append(cells[1].find(text = True))
            D.append(cells[2].find(text = True))
            E.append(cells[3].find(text = True))
            F.append(cells[4].find(text = True))
            G.append(cells[5].find(text = True))

# %%
for line in right_table:
    for row in line.find_all("tr"):
        cells = row.find_all('td')
        states = row.find_all('th')

# %%
states[0]
# Out:
# <th scope="row"><a href="/wiki/West_Bengal" title="West Bengal">West Bengal</a></th>

# %%
df = pd.DataFrame(A, columns=['Number'])

# %%
df['State/UT'] = B
df['Admin Capital'] = C
df['Legitative Capital'] = D
df['Judiciary Capital'] = E
df['Year_Capital'] = F
df['Former_Capital'] = G

# %%
df

# %%
## Extract tables from wikipedia page - Exercise
url = "https://en.wikipedia.org/wiki/List_of_countries_and_capitals_with_currency_and_language"
page = urllib2.urlopen(url)
soup = BeautifulSoup(page)

# %%
soup.prettify()
# Out:
# u'<!DOCTYPE html>\n<html class="client-nojs" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   List of countries and capitals with currency and language - Wikipedia, the free encyclopedia\n  </title>\n  <script>\n   document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );\n  </script>\n  <script>\n   window.RLQ = window.RLQ || []; window.RLQ.push( function () {\nmw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_and_capitals_with_currency_and_language","wgTitle":"List of countries and capitals with currency and language","wgCurRevisionId":686806880,"wgRevisionId":686806880,"wgArticleId":38064145,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["All articles with dead external links","Articles with dead external links from May 2010","Articles with dead
# ...

# %%
all_links = soup.find_all('a')
for link in all_links:
    print link.get('href')
# Out:
# None
# #mw-head
# #p-search
# /wiki/Wikipedia:Deletion_policy
# /wiki/Wikipedia:Articles_for_deletion/List_of_countries_and_capitals_with_currency_and_language
# /wiki/Wikipedia:Articles_for_deletion
# /wiki/Wikipedia:Guide_to_deletion
# /wiki/Sovereign_state
# /wiki/Dependent_territory
# /wiki/World
# /wiki/Continent
# /wiki/National_flag
# /wiki/National_capital
# /wiki/Africa
# /wiki/Asia
# /wiki/Europe
# /wiki/North_America
# /wiki/South_America
# /wiki/Oceania
# /wiki/Antarctica
# /wiki/Eurasia
# /wiki/Americas
# /wiki/Continent#Definitions_and_application
# /wiki/List_of_countries_spanning_more_than_one_continent
# #Africa
# #Asia
# #Europe
# #North_America
# #South_America
# #Oceania
# #Antarctica
# #See_also
# #Notes
# #References
# #External_links
# /w/index.php?title=List_of_countries_and_capitals_with_currency_and_language&action=edit&section=1
# /wiki/File:Africa_(orthographic_projection).svg
# #cite_note-esa.un.org-1
# ...

# %%
table = soup.find_all('table', {"class" : "wikitable sortable"})

# %%
table
# Out:
# [<table class="wikitable sortable">
#  <tr>
#  <th class="unsortable">Flag</th>
#  <th>Name</th>
#  <th>Capital</th>
#  <th>Currency</th>
#  <th>Official language</th>
#  </tr>
#  <tr>
#  <td><span class="flagicon"><a href="/wiki/Algeria" title="Algeria"><img alt="Algeria" class="thumbborder" data-file-height="600" data-file-width="900" height="33" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/50px-Flag_of_Algeria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/75px-Flag_of_Algeria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/100px-Flag_of_Algeria.svg.png 2x" width="50"/></a></span></td>
#  <td><b><a href="/wiki/Algeria" title="Algeria">Algeria</a></b></td>
#  <td><a href="/wiki/Algiers" title="Algiers">Algiers</a></td>
#  <td><a href="/wiki/Dinar" title="Dinar">Dinar</a></td>
#  <td><a href="/wiki/Arabic" title="Arabic">Arabic</a></td>
#  </tr>
#  <tr>
# ...

# %%
A = []
B = []
C = []
D = []
for lines in table:
    for line in lines.find_all('tr'):
        cell = line.find_all('td')        
    if len(cell) == 5:
        A.append(cell[1].find(text = True))

# %%
A
# Out:
# [u'Zimbabwe',
#  u'Yemen',
#  u'Vatican City',
#  u'United States Virgin Islands',
#  u'Venezuela',
#  u'Wallis and Futuna',
#  u'South Georgia and the South Sandwich Islands']
